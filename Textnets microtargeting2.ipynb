# %% [markdown]
# MICROTARGETING AND THE U.S. 2020 ELECTION
#
# What is the discourse of Twitter about microtargeting and the 2020 U.S. presidential election?
#
# The background to this question is that micro-targeting during the 2016 presidential campaign increased the likelihood for Republicans, especially those without a college degree (Donald Trump’s core supporters), to vote by 5-10 percent (Liberini et al. 2018, 5). In other words, micro-targeting might have helped Donald Trump win the election, which is further reflected in the fact that the Trump campaign spent 47 percent of its budget on digital media, compared to the Clinton’s campaign’s 8 percent (Liberini et al. 2018, 2). Liberini expresses this to be “further evidence that recent political outcomes, such as Brexit and the election of President Trump, might be largely due to the use of data analytics” (Kiggins 2018).
#
# Liberini, Federica et al. 2018. The Warwick Economics Research Paper Series (TWERPS) Politics in the Facebook Era Evidence from the 2016 US Presidential Elections. University of Warwick, Department of Economics. https://ideas.repec.org/p/wrk/warwec/1181.html (May 2, 2020).
#
# Kiggins, Sheila. 2018. “Facebook Political Advertising Boosted Trump Turnout by up to Ten per Cent in the 2016 Elections, Research Finds.” https://warwick.ac.uk/newsandevents/pressreleases/facebook_political_advertising/ (May 5, 2020).

# %%
import tweepy
from twitter_authentication import CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

# %%
import json
import csv
from datetime import date
from datetime import datetime
import requests
import pprint
import time
import pandas as pd
import GetOldTweets3 as got
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-c7d55d254d3f> in <module>
#       7 import time
#       8 import pandas as pd
# ----> 9 import GetOldTweets3 as got
#
# ModuleNotFoundError: No module named 'GetOldTweets3'

# %%
#I used this code to harvest tweets in five batches, for the time period of 2018-06-01 to 2020-05-27. I'm only showing the code for the last batch.

#The two lines of code below open a file and then prep it for storing data
csvFile = open('microtargeting_microtarget_oldtweets7.csv', 'a', encoding='utf8')
csvWriter = csv.writer(csvFile)

#This section searches for the data that you need. It would be api.search for you
tweetCriteria = got.manager.TweetCriteria().setQuerySearch('microtargeting OR microtarget')\
                                           .setSince("2018-06-01")\
                                           .setUntil("2018-10-17")\
                                           .setMaxTweets(2500)

tweets = got.manager.TweetManager.getTweets(tweetCriteria);

#This writes my tweet into the csv file that is open
for tweet in tweets:
    csvWriter.writerow([tweet.username, tweet.text, tweet.date])
     
csvFile.close()

# %%
pip install textnets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from textnets import Corpus, Textnet

# %%
from textnets import examples

# %%
from textnets import Corpus, Textnet
import igraph

# %%
#JANUARY TO MAY 2020 - the public conversation on Twitter about micro-targeting

data = pd.read_csv('./microtargeting_microtarget_oldtweets2.csv',
                   names = ['username','text','date'])

corpus = Corpus(pd.Series(data.text.unique())) # The "unique()" eliminates duplicate tweets
np = corpus.noun_phrases()

tn = Textnet(np, min_docs=10)

words = tn.project(node_type='term')
words.plot(label_nodes=True,
           show_clusters=True)

# %%
#NOVEMBER 2019 TO JANUARY 2020 - depiction of the public conversation on Twitter about micro-targeting

data = pd.read_csv('./microtargeting_microtarget_oldtweets3.csv',
                   names = ['username','text','date'])

corpus = Corpus(pd.Series(data.text.unique())) # The "unique()" eliminates duplicate tweets
np = corpus.noun_phrases()

tn = Textnet(np, min_docs=15)

words = tn.project(node_type='term')
words.plot(label_nodes=True,
           show_clusters=True)

# %%
#AUGUST TO NOVEMBER 2019 - depiction of the public conversation on Twitter about micro-targeting

data = pd.read_csv('./microtargeting_microtarget_oldtweets4.csv',
                   names = ['username','text','date'])

corpus = Corpus(pd.Series(data.text.unique())) # The "unique()" eliminates duplicate tweets
np = corpus.noun_phrases()

tn = Textnet(np, min_docs=12)

words = tn.project(node_type='term')
words.plot(label_nodes=True,
           show_clusters=True)

# %%
#MARCH TO AUGUST 2019 - the public conversation on Twitter about micro-targeting

data = pd.read_csv('./microtargeting_microtarget_oldtweets5.csv',
                   names = ['username','text','date'])

corpus = Corpus(pd.Series(data.text.unique())) # The "unique()" eliminates duplicate tweets
np = corpus.noun_phrases()

tn = Textnet(np, min_docs=12)

words = tn.project(node_type='term')
words.plot(label_nodes=True,
           show_clusters=True)

# %%
#OCTOBER 2018 TO MARCH 2019 - the public conversation on Twitter about micro-targeting

data = pd.read_csv('./microtargeting_microtarget_oldtweets6.csv',
                   names = ['username','text','date'])

corpus = Corpus(pd.Series(data.text.unique())) # The "unique()" eliminates duplicate tweets
np = corpus.noun_phrases()

tn = Textnet(np, min_docs=19)

words = tn.project(node_type='term')
words.plot(label_nodes=True,
           show_clusters=True)

# %%
#JUNE TO OCTOBER 2018 - depiction of the public conversation on Twitter about micro-targeting

data = pd.read_csv('./microtargeting_microtarget_oldtweets7.csv',
                   names = ['username','text','date'])

corpus = Corpus(pd.Series(data.text.unique())) # The "unique()" eliminates duplicate tweets
np = corpus.noun_phrases()

tn = Textnet(np, min_docs=20)

words = tn.project(node_type='term')
words.plot(label_nodes=True,
           show_clusters=True)

# %%
#Creating a dataframe for all tweets June 2018 until May 2020:

df = pd.DataFrame(columns=['username', 'text', 'date'])
for i in range(2,8):
    df_temp = pd.read_csv(f'./microtargeting_microtarget_oldtweets{i}.csv', names = ['username','text','date'])
    df = df.append(df_temp)

# %%
#checking that it works
print(df)
# Out:
#             username                                               text  \
# 0     QueenOliviaStR  Proposed bill would ban microtargeting of poli...
# 1        geoffsalmon  Microtargeting fake news via social media also...
# 2      DataAugmented  Proposed Bill Would Ban Microtargeting of Poli...
# 3        evanderburg  Proposed Bill Would Ban Microtargeting of Poli...
# 4              sNerf  Proposed Bill Would Ban Microtargeting of Poli...
# ...              ...                                                ...
# 1813          snbchf  How Far Down the Big Data/'Psychographic Micro...
# 1814         maijoka  Microtargeting bei #thegoodfight Ich weiß auch...
# 1815          snbchf  How Far Down the Big Data/'Psychographic Micro...
# 1816      mariattnnm  @NOIZChain http://noizchain.com #NOIZ #NOIZCHA...
# 1817          snbchf  How Far Down the Big Data/'Psychographic Micro...
#
#                            date
# 0     2020-05-27 23:57:27+00:00
# 1     2020-05-27 23:33:47+00:00
# ...

# %%
#The big picture discussion on microtargeting during these years (each node represents a minimum of 100 tweets)
data = df

corpus = Corpus(pd.Series(data.text.unique())) # The "unique()" eliminates duplicate tweets
np = corpus.noun_phrases()

tn = Textnet(np, min_docs=100)

words = tn.project(node_type='term')
words.plot(label_nodes=True,
           show_clusters=True)

# %%
#The more fine grained discussion on microtargeting during June 2018 until May 2020 (each node represents a minimum of 60 tweets)data = df
data = df

corpus = Corpus(pd.Series(data.text.unique())) # The "unique()" eliminates duplicate tweets
np = corpus.noun_phrases()

tn = Textnet(np, min_docs=70)

words = tn.project(node_type='term')
words.plot(label_nodes=True,
           show_clusters=True)
